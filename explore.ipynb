# %%
import json

# %%
with open("data/dotwatcher_bikes_cleaned.json", "r") as f:
    data = json.load(f)

race_titles = []

for item in data:
    race = item['title'] 
    race_titles.append(race)

race_titles
# Out:
# ['GranGuanche Audax Trail 2025',
#  'Further Elements 2025',
#  'Peninsular Divide 2025',
#  'the Tour de Farce 2025',
#  'Trans Pyrenees Race 2025',
#  'Pirenaica 2025',
#  'Istra Land 2025',
#  'Bohemian Border Bash Race 2025',
#  "Lakes 'n' Knödel 2025",
#  'Sneak Peaks 2025',
#  'Further Perseverance Pyrénées 2025',
#  'Supergrevet Vienna Berlin 2025',
#  'the Log Drivers Waltz 2025',
#  'The Land Between 2025',
#  'Ardennes Monster 2025',
#  'Bentang Jawa 2025',
#  'GBDURO25',
#  'Super-Brevet Berlin-Munich-Berlin 2025',
#  'Basajaun 2025',
#  'VIA Race 2025',
#  'Transcontinental Race No11',
#  'The Hills Have Bikes 2025',
#  'Utrecht Ultra XL 2025',
#  'the Capitals By PedAlma 2025',
#  'Three Peaks Bike Race 2025',
#  'the Bright Midnight 2025',
#  'Pure Peak Grit 2025',
#  'Andean Raid 2025',
#  'Transpyrenees by Transibérica 2025',
#  'Dead Ends and Cake 2025',
#  'Solstice Sprint 2025',
#  'Bike of the Tour Divide: DotWatcher Team Edition',
# ...
